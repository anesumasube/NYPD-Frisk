# %% [markdown]
# # NYC Stop, Question, and Frisk
# Contributors: Anesu Masube and Stephen Williams

# %% [markdown]
# ## Table of Contents

# %% [markdown]
# <a id='toc'></a>
# 1. [Problem Statement](#problemstatement)
# 2. [Import Libraries](#datasources)
# 3. [Data Sources](#datacleaning)
# 4. [Data Cleaning and Feature Engineering](#multicollinearity)
# 4. [Modelling and Cross Validation](#regression)
# 5. [Findings](#findings)
# 6. [Vizualizations](#findings)
# 7. [Next Steps](#nextsteps)

# %% [markdown]
# ## Problem Statement
# **Can Data help to explain and predict arrests in New York City?**
#
#
# Our goal is to use data provided by the New York City police department in every police incident with civilian under The Stop, Question and Frisk program. Using feautures in this data we aimed to construct a model to predict whether or not an incident would result in an arrest.

# %% [markdown]
# ## Import Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.svm import SVC
from xgboost import XGBClassifier
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline
import yellowbrick
import seaborn as sns

# %% [markdown]
# ## Data Source
# [NYC Stop, Question, and Frisk Data from 2018](https://www1.nyc.gov/site/nypd/stats/reports-analysis/stopfrisk.page)
#
# - We used 2018 data from NYPD Stop and Frisk website.
#
# - The data consists of before, during and after feautrues that happen on every recorded incident. All the data is recorded and complied by NYPD.
#
# - About 1200 rows of data with over 70 features before categorical encoding.

# %%
df = pd.read_csv('cleaned_df.csv', index_col = 0)

# %% [markdown]
# ## Data Cleaning and Feature Engineering
# Initial data exploration revealed that many categories of the categorical features were sparse (which can be viewed in the [stephen.ipynb](http://localhost:8888/notebooks/stephen.ipynb)) or had many nulls.  To avoid throwing away too much information, nulls were considered to be their own category.  The null values for numerical features suspect height and weight were removed, and then both columns were converted to floats.  Age was binned.  Those columns that contained unique serial numbers, unique entry documentation, or ex post facto information were dropped.  The cleaner DataFrame was exported as [cleaned_df.csv](http://localhost:8888/edit/cleaned_df.csv).

# %% [markdown]
# ## Modeling and Cross-Validation
# We split the data into train and test sets with a test size of 0.2 of the 10474 observations.  OneHotEncoder was used to generate dummy variable columns for the categorical variables and StandardScaler was used on the numerical variables.
#
# ### Models Considered
#
# -Random Rorest Ensemble
# -Support Vector Machine classifier (with a radial basis function kernel)
# -Gradient Boost classifier (XGBoost)
#
# Grid search cross-validation was used to tune the hyperparameters.  Their ultimate specifications can be viewed in [models.py](http://localhost:8888/edit/models.py).
#
# Given that the gradient boost was prohibitively expensive in terms of time, few iterations were used to tune it, so its forthcoming results should be taken tentatively relative to the performance of the other models.

# %%
# %run -i "models.py"

# %% [markdown]
# ### Model Metrics
# For accuracy, precision, recall, and f1 score, the random forest model outperformed the other models.  Their confusion matrices (using the training set) illustrate this in a more intuitive fashion (the details can be seen in the appendix).

# %% [markdown]
# Given that we are interested in how well this random forest model will perform on new data, the following metrics are composed using the test set of data.

# %%
print(classification_report(y_test, rf_test_pred))
# Out:
#               precision    recall  f1-score   support
#
#            N       0.90      0.96      0.93      1504
#            Y       0.88      0.73      0.80       591
#
#     accuracy                           0.89      2095
#    macro avg       0.89      0.84      0.86      2095
# weighted avg       0.89      0.89      0.89      2095

# %% [markdown]
# Interpretability is of particular interest, namely, those features that were considered most important by our model, so the following is a list of measured importance (as is determined by gini importance) in descending order.  For brevity, we have limited it to display the top ten.

# %%
pd.DataFrame([X_train_new.columns, final_rf.feature_importances_])
tup = list(zip(X_train_new.columns, final_rf.feature_importances_))
sorted(tup, key=lambda x: x[1], reverse=True)[0:11]
# Out:
# [('SEARCHED_FLAG_Y', 0.15280367576266474),
#  ('SEARCHED_FLAG_N', 0.15004878036689098),
#  ('OTHER_CONTRABAND_FLAG_N', 0.02961241965655696),
#  ('SEARCH_BASIS_CONSENT_FLAG_Y', 0.02612688325475333),
#  ('WEAPON_FOUND_FLAG_Y', 0.025491575754276713),
#  ('OTHER_CONTRABAND_FLAG_Y', 0.02521254610959111),
#  ('WEAPON_FOUND_FLAG_N', 0.022622886740363925),
#  ('STOP_DURATION_MINUTES', 0.022136067119698566),
#  ('SEARCH_BASIS_CONSENT_FLAG_(null)', 0.021477280754496238),
#  ('SUSPECTED_CRIME_DESCRIPTION_CPW', 0.017356320651935337),
#  ('SUSPECT_WEIGHT', 0.01615839674033079)]

# %% [markdown]
# ## Future Recommendations
#
# 1. **These results are contingent upon the dataset and methods employed.** Incorporating more granular information related to time and income, we expect that the models would have greater explanatory power. Expanding the span of time would permit for seeing if these results hold true across time periods
#
# 2. **With time, we seek to try additional models** Should time have permitted, it is possible for the XGBoost to have outperformed the random forest, and then different features could be considered most important
#
# 3. **Get balanced data from judiciary system and civil sociaety.** It should be mentioned that this does not answer normative questions like "should have been arrested."  For those types of questions, we would require judicial data and perhaps those who have been released after new evidence comes to light.

# %% [markdown]
# ## Appendix

# %% [markdown]
# ### Random Forest Training Set Classification Report

# %%
print(classification_report(y_train, rf_train_pred))
# Out:
#               precision    recall  f1-score   support
#
#            N       0.93      0.99      0.96      5945
#            Y       0.96      0.82      0.89      2434
#
#     accuracy                           0.94      8379
#    macro avg       0.95      0.90      0.92      8379
# weighted avg       0.94      0.94      0.94      8379

# %% [markdown]
# ### SVM Training Set Classification Report

# %%
print(classification_report(y_train, svc_train_pred))
# Out:
#               precision    recall  f1-score   support
#
#            N       0.89      0.97      0.92      5945
#            Y       0.89      0.70      0.78      2434
#
#     accuracy                           0.89      8379
#    macro avg       0.89      0.83      0.85      8379
# weighted avg       0.89      0.89      0.88      8379

# %% [markdown]
# ### XGBoost Training Set Classification Report

# %%
print(classification_report(y_train, xgb_train_pred))
# Out:
#               precision    recall  f1-score   support
#
#            N       0.91      0.98      0.94      5945
#            Y       0.93      0.76      0.84      2434
#
#     accuracy                           0.91      8379
#    macro avg       0.92      0.87      0.89      8379
# weighted avg       0.91      0.91      0.91      8379

# %% [markdown]
# ### Confusion Matrices

# %%
# %run -i "confusion_matrices.py"
